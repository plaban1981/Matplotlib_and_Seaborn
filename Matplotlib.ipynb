# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#defines a function of two scalar variables and returns a scalar result.
#The class vectorize can be used to “vectorize “this function so that
def addmultiply(a,b):
    if a > b:
        return a * b
    else:
        return a + b

# %%
vec_addm = np.vectorize(addmultiply)
vec_addm([0,4,6,9],[1,6,5,7])
# Out:
# array([ 1, 10, 30, 63])

# %%
import scipy.special as sc
#Binary entropy is entropy of a binary discrete random variable with probability p i
#implement an entropy function
def binary_entropy(x):
    return -(sc.xlogy(x, x) + sc.xlog1py(1 - x, -x))/np.log(2)
binary_entropy(0.80)
# Out:
# 0.72192809488736231

# %%
#using quad function find integration of a*x**2+b in the range 0,1
from scipy.integrate import quad
def integrand(x, a, b):
    return a*x**2 + b
a = 2
b = 1
I = quad(integrand, 0, 1, args=(a,b))
I
# Out:
# (1.6666666666666667, 1.8503717077085944e-14)

# %%
np.sign(10)
# Out:
# 1

# %% [markdown]
# Find the inverse of a matrix

# %%
import numpy as np
from scipy import linalg ## linear algebra library
A = np.array([[1,3,5],[2,5,1],[2,3,8]])
print("Matrix: \n",A)
inv_mat = linalg.inv(A)
print("Inverse matrix:\n",inv_mat)
# Out:
# Matrix:
#  [[1 3 5]
#  [2 5 1]
#  [2 3 8]]
# Inverse matrix:
#  [[-1.48  0.36  0.88]
#  [ 0.56  0.08 -0.36]
#  [ 0.16 -0.12  0.04]]

# %%
## Double check, dot product of matrix with its inverse matrix is a identity matrix
A.dot(linalg.inv(A)).astype(int)
# Out:
# array([[1, 0, 0],
#        [0, 0, 0],
#        [0, 0, 1]])

# %%
# create an arbitrary 3 variable linear equations system and solve the equations
A = np.array([[1, 2], [3, 4]])
print("Matrix A:/n", A)
b = np.array([[5], [6]])
print("Matrix b:\n", b)
# Out:
# Matrix A:/n [[1 2]
#  [3 4]]
# Matrix b:
#  [[5]
#  [6]]

# %%
np.linalg.solve(A, b) # easy approch
# Out:
# array([[-4. ],
#        [ 4.5]])

# %%
linalg.inv(A).dot(b) #slow
# Out:
# array([[-4. ],
#        [ 4.5]])

# %%
A.dot(linalg.inv(A).dot(b))
# Out:
# array([[ 5.],
#        [ 6.]])

# %%
(A.dot(linalg.inv(A).dot(b)) - b).astype(int) # check
# Out:
# array([[0],
#        [0]])

# %% [markdown]
# Find the determinant of a 3X3 matrix

# %%
A = np.array([[1,2,3],[0,1,4],[5,6,0]])
A
# Out:
# array([[1, 2, 3],
#        [0, 1, 4],
#        [5, 6, 0]])

# %%
linalg.det(A)
# Out:
# 0.9999999999999987

# %% [markdown]
# Compute eigen values and eigen vector of the above matrix A

# %%
la, v = linalg.eig(A)
l1, l2 , l3 = la
print(l1, l2, l3) # eigenvalues
print(v[:, 0]) # first eigenvector
print(v[:, 1]) # second eigenvector
print(v[:, 2]) # third eigenvector
# Out:
# (-5.22966960048+0j) (-0.026352822204+0j) (7.25602242269+0j)
# [ 0.22578016  0.52634845 -0.81974424]
# [-0.75769839  0.63212771 -0.16219652]
# [-0.49927017 -0.46674201 -0.72998712]

# %% [markdown]
# Find SVD from the above matrix

# %%
M,N = A.shape ## give the matrix shape

# %%
U,s,Vh = linalg.svd(A) ## svd is applied

# %%
Sig = linalg.diagsvd(s,M,N) ## getting diagolnal matrix

# %%
U, Vh = U, Vh

# %%
U.dot(Sig.dot(Vh)) #check computation
# Out:
# array([[  1.00000000e+00,   2.00000000e+00,   3.00000000e+00],
#        [  2.27910397e-16,   1.00000000e+00,   4.00000000e+00],
#        [  5.00000000e+00,   6.00000000e+00,  -8.41195827e-16]])

# %%
## Three decomposed matrix
U
# Out:
# array([[-0.33780332, -0.51318841, -0.78900353],
#        [-0.19885965, -0.78044262,  0.59275978],
#        [-0.91996943,  0.35713718,  0.16158364]])

# %%
Vh
# Out:
# array([[-0.59641821, -0.77236466, -0.2184906 ],
#        [ 0.26271876,  0.06937103, -0.96237545],
#        [ 0.75846171, -0.63137983,  0.16154054]])

# %%
Sig
# Out:
# array([[ 8.27883923,  0.        ,  0.        ],
#        [ 0.        ,  4.84357297,  0.        ],
#        [ 0.        ,  0.        ,  0.02493818]])

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
## plt.show() for non-notebook users

# %%
x = np.arange(0,200)
y = x*4
z = x**4


fig = plt.figure()
axis = fig.add_axes([0,0,1,1])
axis.plot(x,y)
axis.set_xlabel('x') # x labels
axis.set_ylabel('y') # y labels
axis.set_title('title')

# %%
# Empty canvas of 1 by 2 subplots
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x,y,color="blue", lw=3, ls='--')
axes[1].plot(x,z,color="red", lw=3, ls='-')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(12,2))
axes[0].plot(x,y,color="blue", lw=5)
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')
axes[1].plot(x,z,color="red", lw=3, ls='--')
axes[1].set_xlabel('x')
axes[1].set_ylabel('z')

# %%
A= np.random.normal(0,10,1000)
B= A/9
# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,2,1)
plt.plot(A, B, 'r--') # More on color options later
plt.subplot(1,2,2)
plt.plot(B, A, 'b*-');

# %%
df = pd.read_csv("winequality-red.csv",delimiter=";")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
plt.hist(df.density, bins=25, color = "skyblue" ) ## try different columns
# Out:
# (array([   3.,    4.,    8.,    6.,   14.,   20.,   50.,   45.,   83.,
#          142.,  164.,  224.,  196.,  199.,  152.,   81.,   64.,   62.,
#           43.,    9.,   14.,    1.,    8.,    1.,    6.]),
#  array([ 0.99007  ,  0.9906148,  0.9911596,  0.9917044,  0.9922492,
#          0.992794 ,  0.9933388,  0.9938836,  0.9944284,  0.9949732,
#          0.995518 ,  0.9960628,  0.9966076,  0.9971524,  0.9976972,
#          0.998242 ,  0.9987868,  0.9993316,  0.9998764,  1.0004212,
#          1.000966 ,  1.0015108,  1.0020556,  1.0026004,  1.0031452,  1.00369  ]),
#  <a list of 25 Patch objects>)

# %%
df.chlorides.nunique()
# Out:
# 153

# %%
df.pH.nunique()
# Out:
# 89

# %%
colors = ("red", "green", "blue")
plt.scatter(df.chlorides, df.pH, c=colors)

# %%
plt.boxplot(df['volatile acidity'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x9eecc18>],
#  'caps': [<matplotlib.lines.Line2D at 0x9ed3fd0>,
#   <matplotlib.lines.Line2D at 0x9ee1e48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x9ef8eb8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x9ee1fd0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x9eece80>,
#   <matplotlib.lines.Line2D at 0x9ed3e48>]}

# %% [markdown]
# # SEABORN

# %%
import seaborn as sns
## Using the same dataset
sns.jointplot(x='volatile acidity',y='citric acid',data=df)

# %%
sns.boxplot(x='quality',y='pH',data=df,palette='rainbow')

# %%
sns.countplot(x='quality',data=df)

# %%
## correlation plot
sns.heatmap(df.corr(),cmap='coolwarm',annot=True)
plt.title('df.corr()')

# %%
## correlation plot
sns.heatmap(df.corr(),cmap='coolwarm')
plt.title('df.corr()')
